# %% [markdown]
# # Preparación de libraries y funciones.

# %% [markdown]
# ## Imports.

# %%
import numpy as np
import pandas as pd
import GetOldTweets3 as got
import datetime
from textblob import TextBlob
import re
import unidecode
import matplotlib.pyplot as plt
import time
import os
import glob

# %% [markdown]
# ## Definición de funciones.
# En esta sección definimos las funciones que vamos a utilizar en la notebook.

# %% [markdown]
# ### Función para obtener los tweets de acuerdo a los criterios de búsqueda.

# %%
def get_tweets(list_criterios, fecha_inicio, fecha_final, maximo=250):
    tweets_total = []
    for criterio in list_criterios:
        tweetCriteria = got.manager.TweetCriteria().setQuerySearch(criterio).setSince(fecha_inicio).setUntil(fecha_final).setMaxTweets(maximo)
        tweets_total = got.manager.TweetManager.getTweets(tweetCriteria)
    return tweets_total

# %% [markdown]
# ### Función para limpiar los tweets.

# %%
def limpiar(tweet_texto):
    text = ' '.join(re.sub(r"(@)|([^0-9A-Za-z \t])|(www.[^ ]+)|(https?://[^ ]+)", "", unidecode.unidecode(tweet_texto.lower())).split())
    return text

# %% [markdown]
# ### Función para crear un dataframe en base a los tweets.

# %%
def create_df(tweets_anuncios):
    datos = []
    for anuncio in tweets_anuncios:
        for ciudad in tweets_anuncios[anuncio]: 
            for tweet in tweets_anuncios[anuncio][ciudad]:
                registro = {'username': tweet.username, 'tweet': limpiar(tweet.text), \
                            'fecha': tweet.date, 'anuncio':anuncio, 'ubicacion':ciudad, 'id':tweet.id}
                datos.append(registro)
    df = pd.DataFrame(data=datos)    
    return df

# %% [markdown]
# ### Función para limpiar dataframe.

# %%
#definimos listas de los usuarios y topics que vamos a eliminar
usuarios_blacklist = ['sergistack', 'GamesRedDeer']
usuarios_medios = ['gustavorearte1','gerdellamonica','radiofonica1007',' pmgcharly',' NTodxs',' Noticiasde_',' nora_verges',' mnspezzapria',' METRO_RADIO_TV',' MartinD50004804',' mariogaloppo',' LUIS20GEREZ',' losprimerostuc',' lacriticaok',' lacapital',' IldefonsoM',' HernanMundo',' elsolquilmes',' ellitoral',' cronica',' cordoba',' Contexto_Tuc',' ConLaGenteRos',' con_sello',' Cadena3Com',' AvellanedaReal',' AiredeSantaFe',' AgenciaDib',' Adry1BC',' ADNsur',' abccordoba',' 104Urbana']
topicos_excluidos = ['pique','barcelona', 'bayern munich', 'barca', 'bayern', 'barsa', 'anabelle', 'annabell', 'annabelle', 'messi', 'balvin', 'pampita']

def clean_up_df(df):
    #definimos una máscara para excluir a los usuarios en la lista negra
    mask_not_bl = [x not in usuarios_blacklist for x in df['username']] 
    df = df[mask_not_bl]
    #definimos una máscara para excluir a los usuarios en la lista negra
    mask_not_media = [x not in usuarios_medios for x in df['username']] 
    df = df[mask_not_media]
    df.drop_duplicates(subset=['tweet'], keep=False, inplace=True)
    # máscara de tópicos excluidos
    mask_not_topics = [x not in topicos_excluidos for x in df['tweet']] 
    df = df[mask_not_topics]
    
    try:
        df.drop(columns=['index'], axis=0, inplace=True)
    except:
        print("No existe la columna index")
        
    try:
        df.drop(columns=['fecha_sola'], axis=0, inplace=True)
    except:
        print("No existe la columna fecha_sola")
        
    return df

# %% [markdown]
# ### Datasets con archivos sucios.

# %% [markdown]
# Obtenemos todos los archivos crudos limpios y los conformamos en un único dataframe:

# %%
path_crudos = 'Data/Crudos/' 
all_files_crudos = glob.glob(path_crudos + "/*.csv")

li_crudos = []

try:
    for filename in all_files_crudos:
        df = pd.read_csv(filename, sep = ';', header=0)
        li_crudos.append(df_sin_clasificar)
    concatenado = pd.concat(li_crudos, axis=0) 
    df = concatenado.drop_duplicates()
    print(df.shape)
except:
    print("No hay archivos en el directorio")
# Out:
# (13857, 8)

# %%
print(df.shape)
df.head(3)
# Out:
# (13857, 8)
#           username  \
# 0  Elizabeth789741
# 1       sergistack
# 2     vickyuliyapo
#
#                                                                                                  tweet  \
# 0  alferdez alferdezprensa por favor qxsea a partir del sabafo la cuarentena los q fuimos hoy a tra...
# 1  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 2  comodice inesazpelicueta que comiencen ya a elaborar remedios genericos asi no nos toma de sorpr...
#
#                        fecha    anuncio                ubicacion  \
# 0  2020-03-19 23:04:48+00:00  Anuncio_1  Buenos Aires, Argentina
# 1  2020-03-28 20:07:18+00:00  Anuncio_1  Buenos Aires, Argentina
# 2  2020-03-19 22:57:33+00:00  Anuncio_1  Buenos Aires, Argentina
#
#              id  sentimiento fecha_sola
# 0  1.240776e+18          NaN        NaN
# 1  1.243993e+18          NaN        NaN
# 2  1.240774e+18          NaN        NaN

# %% [markdown]
# # Limpieza.

# %% [markdown]
# Tamaño del dataset previo a la limpieza:

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', 100)

# %% [markdown]
# ### Por usuarios específicos.

# %% [markdown]
# #### Trolls.

# %%
mask_bl = [x in usuarios_blacklist for x in df['username']]

# %%
df.loc[mask_bl, ['username','tweet']]
# Out:
#           username  \
# 1       sergistack
# 34      sergistack
# 10      sergistack
# 34    GamesRedDeer
# 42    GamesRedDeer
# 53    GamesRedDeer
# 43    GamesRedDeer
# 133   GamesRedDeer
# 148   GamesRedDeer
# 348   GamesRedDeer
# 408   GamesRedDeer
# 470   GamesRedDeer
# 585     sergistack
# 612   GamesRedDeer
# 633   GamesRedDeer
# 648   GamesRedDeer
# 866     sergistack
# 887   GamesRedDeer
# 977   GamesRedDeer
# 1034  GamesRedDeer
# 1087  GamesRedDeer
# 1102    sergistack
# 1192  GamesRedDeer
# 1228  GamesRedDeer
# 1295  GamesRedDeer
# 1436  GamesRedDeer
# 1526  GamesRedDeer
# 1589    sergistack
# 1615  GamesRedDeer
# 1631  GamesRedDeer
# 1673  GamesRedDeer
# 1834  GamesRedDeer
# 1847    sergistack
# 1868  GamesRedDeer
# 1937  GamesRedDeer
# 1943  GamesRedDeer
# 2168  GamesRedDeer
# 2195  GamesRedDeer
# 2231    sergistack
# 2279  GamesRedDeer
# 2447    sergistack
# 2468  GamesRedDeer
# 2489  GamesRedDeer
# 2537  GamesRedDeer
# 2558  GamesRedDeer
# 43    GamesRedDeer
# 280   GamesRedDeer
# 669   GamesRedDeer
# 740   GamesRedDeer
# 888   GamesRedDeer
# 1019  GamesRedDeer
# 1076  GamesRedDeer
# 1736  GamesRedDeer
# 1845    sergistack
# 1887  GamesRedDeer
# 2313  GamesRedDeer
# 2601  GamesRedDeer
# 2712  GamesRedDeer
# 510   GamesRedDeer
# 552   GamesRedDeer
# 593   GamesRedDeer
# 923   GamesRedDeer
# 1822  GamesRedDeer
# 1       sergistack
# 22    GamesRedDeer
# 190   GamesRedDeer
# 443   GamesRedDeer
# 452     sergistack
# 757     sergistack
# 973   GamesRedDeer
# 22      sergistack
# 432     sergistack
# 714     sergistack
# 1       sergistack
# 301     sergistack
# 583     sergistack
# 871     sergistack
# 1086    sergistack
# 1316    sergistack
# 1595    sergistack
# 1853    sergistack
# 2153    sergistack
# 1       sergistack
# 301     sergistack
# 583     sergistack
# 871     sergistack
# 1094    sergistack
# 1276    sergistack
# 1576    sergistack
# 1827    sergistack
# 2127    sergistack
# 22      sergistack
# 301     sergistack
# 583     sergistack
# 857   GamesRedDeer
# 871     sergistack
# 1082    sergistack
# 1282  GamesRedDeer
# 1297    sergistack
# 1603  GamesRedDeer
# 1618    sergistack
# 1828    sergistack
# 1945  GamesRedDeer
# 2128    sergistack
#
#                                                                                                     tweet
# 1     usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 34    usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 10    usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 34    waiting for fallguys on nintendo try now joy of clumsyrush cosy party game fallguysgame nintendo...
# 42    brawl chess coming soon follow to play brawlchess retweet if you play chess chess chiesu szachy ...
# 53    do you remember the times when highscore was what really mattered cyberprotocol77 is coming to s...
# 43    brawl chess coming soon follow to play brawlchess retweet if you play chess chess chiesu szachy ...
# 133   the end of the world is not the worst thing that can happen to us do you like space horrors we h...
# 148   they say its one of the hardest logic game ever 100 levels global ranking try now nintendo xbox ...
# 348   waiting for fallguys on nintendo try now joy of clumsyrush cosy party game fallguysgame nintendo...
# 408   the end of the world is not the worst thing that can happen to us do you like space horrors we h...
# 470   do you remember the times when highscore was what really mattered cyberprotocol77 is coming to s...
# 585   usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 612   they say its one of the hardest logic game ever 100 levels global ranking try now nintendo xbox ...
# 633   do you remember the times when highscore was what really mattered cyberprotocol77 is coming to s...
# 648   the end of the world is not the worst thing that can happen to us do you like space horrors we h...
# 866   usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 887   they say its one of the hardest logic game ever 100 levels global ranking try now nintendo xbox ...
# 977   brawl chess coming soon follow to play brawlchess retweet if you play chess chess chiesu szachy ...
# 1034  do you remember the times when highscore was what really mattered cyberprotocol77 is coming to s...
# 1087  the end of the world is not the worst thing that can happen to us do you like space horrors we h...
# 1102  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1192  waiting for fallguys on nintendo try now joy of clumsyrush cosy party game fallguysgame nintendo...
# 1228  do you remember the times when highscore was what really mattered cyberprotocol77 is coming to s...
# 1295  do you remember the times when highscore was what really mattered cyberprotocol77 is coming to s...
# 1436  brawl chess coming soon follow to play brawlchess retweet if you play chess chess chiesu szachy ...
# 1526  waiting for fallguys on nintendo try now joy of clumsyrush cosy party game fallguysgame nintendo...
# 1589  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1615  brawl chess coming soon follow to play brawlchess retweet if you play chess chess chiesu szachy ...
# 1631  they say its one of the hardest logic game ever 100 levels global ranking try now nintendo xbox ...
# 1673  waiting for fallguys on nintendo try now joy of clumsyrush cosy party game fallguysgame nintendo...
# 1834  do you remember the times when highscore was what really mattered cyberprotocol77 is coming to s...
# 1847  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1868  brawl chess coming soon follow to play brawlchess retweet if you play chess chess chiesu szachy ...
# 1937  the end of the world is not the worst thing that can happen to us do you like space horrors we h...
# 1943  do you remember the times when highscore was what really mattered cyberprotocol77 is coming to s...
# 2168  brawl chess coming soon follow to play brawlchess retweet if you play chess chess chiesu szachy ...
# 2195  the end of the world is not the worst thing that can happen to us do you like space horrors we h...
# 2231  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 2279  they say its one of the hardest logic game ever 100 levels global ranking try now nintendo xbox ...
# 2447  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 2468  brawl chess coming soon follow to play brawlchess retweet if you play chess chess chiesu szachy ...
# 2489  the end of the world is not the worst thing that can happen to us do you like space horrors we h...
# 2537  do you remember the times when highscore was what really mattered cyberprotocol77 is coming to s...
# 2558  they say its one of the hardest logic game ever 100 levels global ranking try now nintendo xbox ...
# 43    waiting for fallguys on nintendo try now joy of clumsyrush cosy party game fallguysgame nintendo...
# 280                  what is your favorite party game have a look on clumsyrush party game nintendoswitch
# 669   waiting for fallguys on nintendo try now joy of clumsyrush cosy party game fallguysgame nintendo...
# 740   the end of the world is not the worst thing that can happen to us do you like space horrors we h...
# 888                  what is your favorite party game have a look on clumsyrush party game nintendoswitch
# 1019  brawl chess coming soon follow to play brawlchess retweet if you play chess chess chiesu szachy ...
# 1076  they say its one of the hardest logic game ever 100 levels global ranking try now nintendo xbox ...
# 1736                 what is your favorite party game have a look on clumsyrush party game nintendoswitch
# 1845  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1887  they say its one of the hardest logic game ever 100 levels global ranking try now nintendo xbox ...
# 2313  the end of the world is not the worst thing that can happen to us do you like space horrors we h...
# 2601  do you remember the times when highscore was what really mattered cyberprotocol77 is coming to s...
# 2712  waiting for fallguys on nintendo try now joy of clumsyrush cosy party game fallguysgame nintendo...
# 510   brawl chess coming soon follow to play brawlchess retweet if you play chess chess chiesu szachy ...
# 552                  what is your favorite party game have a look on clumsyrush party game nintendoswitch
# 593   they say its one of the hardest logic game ever 100 levels global ranking try now nintendo xbox ...
# 923   brawl chess coming soon follow to play brawlchess retweet if you play chess chess chiesu szachy ...
# 1822  the end of the world is not the worst thing that can happen to us do you like space horrors we h...
# 1     usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 22    they say its one of the hardest logic game ever 100 levels global ranking try now nintendo xbox ...
# 190   brawl chess coming soon follow to play brawlchess retweet if you play chess chess chiesu szachy ...
# 443   the end of the world is not the worst thing that can happen to us do you like space horrors we h...
# 452   usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 757   usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 973                  what is your favorite party game have a look on clumsyrush party game nintendoswitch
# 22    usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 432   usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 714   usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1     usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 301   usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 583   usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 871   usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1086  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1316  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1595  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1853  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 2153  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1     usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 301   usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 583   usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 871   usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1094  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1276  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1576  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1827  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 2127  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 22    usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 301   usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 583   usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 857   big game pack giveaway click amp win omg police omgpolice clumsy rush clumsyrush nirvanapilotyum...
# 871   usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1082  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1282                    awesome game prize pack xbox nintendo eshop complete your entry here 4 x giveaway
# 1297  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1603  big game pack giveaway click amp win omg police omgpolice clumsy rush clumsyrush nirvanapilotyum...
# 1618  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1828  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...
# 1945  big game pack giveaway click amp win omg police omgpolice clumsy rush clumsyrush nirvanapilotyum...
# 2128  usas google chrome lo siento por las mayusculas pero existe un nuevo navegador que es mas rapido...

# %% [markdown]
# #### Medios de comunicación.

# %%
df_medios = pd.read_csv('Data/Clasificados/usuarios_mas_10_tweets_clasificados.csv', sep=';')

# %%
mask_media = [x in usuarios_medios for x in df_medios['username']]

# %%
df_medios.loc[mask_media, ['username','tweet']].sample(20)
# Out:
#             username  \
# 97   radiofonica1007
# 483   gerdellamonica
# 474   gustavorearte1
# 464   gustavorearte1
# 486   gerdellamonica
# 473   gustavorearte1
# 471   gustavorearte1
# 475   gustavorearte1
# 478   gerdellamonica
# 479   gerdellamonica
# 461   gustavorearte1
# 101  radiofonica1007
# 481   gerdellamonica
# 459   gustavorearte1
# 472   gustavorearte1
# 485   gerdellamonica
# 488   gerdellamonica
# 463   gustavorearte1
# 476   gustavorearte1
# 98   radiofonica1007
#
#                                                                                                    tweet
# 97       14 de agosto curvas de la evolucion del coronavirus en rosario santa fe y argentina radiofonica
# 483  reportan otros 3 casos de coronavirus en la provincia de santa fe 2 de la ciudad capital y 1 de ...
# 474  la oms afirma que no hay evidencia de que una persona que se haya recuperado del coronavirus no ...
# 464  un estudio publicado en the new england journal of medicine demuestra que un virus permanece has...
# 486                                       monte vera otra vez con 9 nuevos casos de coronavirus tremendo
# 473  argentina no tiene plata para auxiliar a su sector productivo entonces generalmente crea bonos a...
# 471  el ministro de salud bonaerense daniel gollan recomendo el uso de tapabocas para minimizar las p...
# 475  poniendo primera la automotriz scania reabre su fabrica de tucuman a partir del lunes retomara s...
# 478                                            la provincia de santa fe no registro casos de coronavirus
# 479  oficial 240 nuevos casos de coronavirus en argentina suman 5611 infectados 1659 recuperados 11 f...
# 461  en lombardia se registraron 319 muertos mas por coronavirus en las ultimas 24 horas y el total d...
# 101           adelanto de 77 nuevos casos de coronavirus en rosario 190 en toda la provincia de santa fe
# 481  se confirman 4 nuevos casos de coronavirus en santafe corresponden a villaocampo todos con nexo ...
# 459  el presidente alberto fernandez tras reunirse con todos los gobernadores del pais se prepara par...
# 472            el coronavirus es feroz en una argentina con un 40 de pobres coronavirusargentina pobreza
# 485                   arroyo leyes registra el primer caso de coronavirus desde el inicio de la pandemia
# 488               la semana termina con un nuevo record santa fe reporta 190 nuevos casos de coronavirus
# 463  el dengue imparable ya llegaron a los 100 casos en chaco en la provincia de tucuman ya se regist...
# 476  coronavirus la universidad de oxford recluta 10 mil voluntarios para probar una vacuna es para l...
# 98     coronavirus en argentina 6365 nuevos contagiados y 99 fallecidos en las ultimas horas radiofonica

# %% [markdown]
# ### Por contenido de tweets.
# #### Duplicados.

# %%
df[df.duplicated(subset=['tweet'])==True].sort_values(by='tweet',ascending=False)
# Out:
#              username  \
# 1676     Jefa04120216
# 1652     Jefa04120216
# 1653     Jefa04120216
# 96    TeleCentroAyuda
# 96    TeleCentroAyuda
# ...               ...
# 2328  Rosana841773501
# 2338  Rosana841773501
# 2339  Rosana841773501
# 2363  Fernand98267834
# 2365  Fernand98267834
#
#                                                                                                     tweet  \
# 1676  zenonbiagosch steinbetina jorgecarreraok arnaldobocco alferdez bancocentralar automoruva alferde...
# 1652  zenonbiagosch steinbetina jorgecarreraok arnaldobocco alferdez bancocentralar automoruva alferde...
# 1653  zenonbiagosch steinbetina jorgecarreraok arnaldobocco alferdez bancocentralar automoruva alferde...
# 96    yolavieja si despues del reseteo no recuperaste el servicio mandanos un mensaje de whats app al ...
# 96    yolavieja si despues del reseteo no recuperaste el servicio mandanos un mensaje de whats app al ...
# ...                                                                                                   ...
# 2328                                                                                                  NaN
# 2338                                                                                                  NaN
# 2339                                                                                                  NaN
# 2363                                                                                                  NaN
# 2365                                                                                                  NaN
#
#                           fecha    anuncio           ubicacion            id  \
# 1676  2020-06-04 18:53:55+00:00  Anuncio_7  Mendoza, Argentina  1.268617e+18
# 1652  2020-06-04 18:53:55+00:00  Anuncio_7  Tucumán, Argentina  1.268617e+18
# 1653  2020-06-04 18:53:55+00:00  Anuncio_7   Paraná, Argentina  1.268617e+18
# 96    2020-03-19 20:06:16+00:00  Anuncio_1  Mendoza, Argentina  1.240731e+18
# 96    2020-03-19 20:06:16+00:00  Anuncio_1   Paraná, Argentina  1.240731e+18
# ...                         ...        ...                 ...           ...
# 2328  2020-07-17 21:20:16+00:00  Anuncio_9   Paraná, Argentina  1.284237e+18
# 2338  2020-07-17 21:16:23+00:00  Anuncio_9   Paraná, Argentina  1.284236e+18
# 2339  2020-07-17 21:16:00+00:00  Anuncio_9   Paraná, Argentina  1.284235e+18
# 2363  2020-07-17 21:01:06+00:00  Anuncio_9   Paraná, Argentina  1.284232e+18
# 2365  2020-07-17 20:59:14+00:00  Anuncio_9   Paraná, Argentina  1.284231e+18
#
#       sentimiento fecha_sola
# 1676          NaN        NaN
# 1652          NaN        NaN
# 1653          NaN        NaN
# 96            NaN        NaN
# 96            NaN        NaN
# ...           ...        ...
# 2328          NaN        NaN
# 2338          NaN        NaN
# 2339          NaN        NaN
# 2363          NaN        NaN
# 2365          NaN        NaN
#
# [9704 rows x 8 columns]

# %% [markdown]
# #### Tópicos no relevantes.

# %%
print(df.shape)
df.dropna(subset=['tweet'], inplace=True)
print(df.shape)
# Out:
# (13857, 8)
# (13469, 8)
# <ipython-input-98-326fdc169b4b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['tweet'], inplace=True)

# %%
topicos_excluidos = ['pique','barcelona', 'bayern munich', 'barca', 'bayern', 'barsa', 'anabelle', 'annabell', 'annabelle', 'messi', 'balvin', 'pampita']

for t in topicos_excluidos:
    mask_topicos = df['tweet'].str.find(t) != -1
    
df.loc[mask_topicos, ['username','tweet']]
# Out:
# Empty DataFrame
# Columns: [username, tweet]
# Index: []

# %% [markdown]
# ### Guardamos el dataset filtrado.

# %%
df.to_csv("Data/Crudos/tweets_crudos_limpios_"+str(time.time())+".csv", sep=';', index=False)

# %% [markdown]
# ## Merge de datasets.

# %% [markdown]
# Con el fin de sumar la mayor cantidad de tweets, es necesario que vayamos armando el dataframe consolidado con los datos que vamos obteniendo de "a cachos".
#
# Por esta razón, tenemos tres datasets:
# 1. Nuevos tweets obtenidos sin clasificar.
# 2. Tweets clasificados.
# 3. Dataframe ya consolidado con todos los tweets obtenidos hasta el momento.

# %% [markdown]
# ### Datasets con archivo consolidado.

# %%
try:
    list_of_files = glob.glob('Data/Consolidado/*.csv') 
    latest_file = max(list_of_files, key=os.path.getctime)
    df_consolidado_nuevo = pd.read_csv(latest_file, sep=';')
except:
    print("No hay archivos en el directorio")

# %%
df_consolidado_nuevo.head()
# Out:
#           username                                              tweet  \
# 0  Elizabeth789741  alferdez alferdezprensa por favor qxsea a part...
# 1       sergistack  usas google chrome lo siento por las mayuscula...
# 2     vickyuliyapo  comodice inesazpelicueta que comiencen ya a el...
# 3       RUCHOCASLA  alferdez alferdezprensa a los que enganchan en...
# 4    Populismomata  alferdezprensa porque no hacen que el indek mi...
#
#                        fecha    anuncio                ubicacion  \
# 0  2020-03-19 23:04:48+00:00  Anuncio_1  Buenos Aires, Argentina
# 1  2020-03-28 20:07:18+00:00  Anuncio_1  Buenos Aires, Argentina
# 2  2020-03-19 22:57:33+00:00  Anuncio_1  Buenos Aires, Argentina
# 3  2020-03-19 20:28:12+00:00  Anuncio_1  Buenos Aires, Argentina
# 4  2020-03-19 17:46:55+00:00  Anuncio_1  Buenos Aires, Argentina
#
#              id sentimiento fecha_sola
# 0  1.240776e+18         NaN        NaN
# 1  1.243993e+18         NaN        NaN
# 2  1.240774e+18         NaN        NaN
# 3  1.240737e+18         NaN        NaN
# 4  1.240696e+18         NaN        NaN

# %%
df_consolidado = clean_up_df(df_consolidado_nuevo)
print(df_consolidado.shape)
df_consolidado.head(3)
# Out:
# No existe la columna index
# (7480, 7)
#              username                                              tweet  \
# 1199  Federic22912449  alferdezprensa fijense el mic por momentos no ...
# 1496        DaniBrie1  esta foto es de ayer alferdez alferdezprensa s...
# 1723       dany000037  alferdezprensa circula esto en el nombre de pr...
#
#                           fecha    anuncio                ubicacion  \
# 1199  2020-05-08 23:50:46+00:00  Anuncio_5  Buenos Aires, Argentina
# 1496  2020-05-23 18:30:48+00:00  Anuncio_6  Buenos Aires, Argentina
# 1723  2020-06-04 20:23:27+00:00  Anuncio_7  Buenos Aires, Argentina
#
#                 id sentimiento
# 1199  1.258907e+18         NaN
# 1496  1.264263e+18         NaN
# 1723  1.268640e+18         NaN

# %% [markdown]
# ### Datasets con archivos sin clasificar.

# %% [markdown]
# Obtenemos todos los archivos crudos limpios y los conformamos en un único dataframe:

# %%
path_crudos = 'Data/Crudos/' 
all_files_crudos = glob.glob(path_crudos + "/*.csv")

li_crudos = []

try:
    for filename in all_files_crudos:
        df_sin_clasificar = pd.read_csv(filename, sep = ';', header=0)
        li_crudos.append(df_sin_clasificar)
    concatenado = pd.concat(li_crudos, axis=0) 
    df_sin_clasificar = concatenado.drop_duplicates()
    print(df_sin_clasificar.shape)
except:
    print("No hay archivos en el directorio")
# Out:
# (13857, 8)

# %%
print(df_sin_clasificar.shape)
df_sin_clasificar.head(3)
# Out:
# (13857, 8)
#           username                                              tweet  \
# 0  Elizabeth789741  alferdez alferdezprensa por favor qxsea a part...
# 1       sergistack  usas google chrome lo siento por las mayuscula...
# 2     vickyuliyapo  comodice inesazpelicueta que comiencen ya a el...
#
#                        fecha    anuncio                ubicacion  \
# 0  2020-03-19 23:04:48+00:00  Anuncio_1  Buenos Aires, Argentina
# 1  2020-03-28 20:07:18+00:00  Anuncio_1  Buenos Aires, Argentina
# 2  2020-03-19 22:57:33+00:00  Anuncio_1  Buenos Aires, Argentina
#
#              id  sentimiento fecha_sola
# 0  1.240776e+18          NaN        NaN
# 1  1.243993e+18          NaN        NaN
# 2  1.240774e+18          NaN        NaN

# %% [markdown]
# ### Dataset con tweets clasificados manualmente.

# %% [markdown]
# Obtenemos todos los archivos con tweets clasificados y los conformamos en un único dataframe:

# %%
path_clasificados = 'Data/Clasificados/' 
all_files_clasificados = glob.glob(path_clasificados + "/*.csv")

li_clasificados = []

try:
    for filename in all_files_clasificados:
        df_clasificados = pd.read_csv(filename, sep = ';', header=0)
        li_clasificados.append(df_clasificados)
        print(filename)
    concatenado = pd.concat(li_clasificados, axis=0) 
    df_clasificados = concatenado.drop_duplicates()
    print(df_clasificados.shape)
except:
    print("No hay archivos en el directorio")
# Out:
# Data/Clasificados\2da_mitad_tweets_clasificados_euge.csv
# Data/Clasificados\parte_gaston.csv
# Data/Clasificados\usuarios_mas_10_tweets_clasificados.csv
# (5731, 8)

# %%
print(df_clasificados.shape)
df_clasificados.head(3)
# Out:
# (5731, 8)
#        username                                              tweet  \
# 0        Mar-14  edufeiok edufeiok te comento tengo a mi hijo c...
# 1  ____Marcos77                             aguante el coronavirus
# 2      __Maxi94  mamita pique ni el coronavirus se agarra porqu...
#
#                        fecha     anuncio                ubicacion fecha_sola  \
# 0  2020-07-31 21:27:55+00:00  Anuncio_10  Buenos Aires, Argentina   31-07-20
# 1  2020-08-14 00:30:36+00:00  Anuncio_11       Cordoba, Argentina   14-08-20
# 2  2020-08-14 19:23:55+00:00  Anuncio_11  Buenos Aires, Argentina   14-08-20
#
#   sentimiento  id
# 0     Neutral NaN
# 1     Neutral NaN
# 2     Neutral NaN

# %%
df_clasificados.sentimiento.value_counts()
# Out:
# Neutral     1891
# Positivo     487
# Negativo     325
# Name: sentimiento, dtype: int64

# %% [markdown]
# ## Merge entre dataset clasificado y sin clasificar.

# %%
print('Cantidad de tweets clasificados en el dataset consolidado, previo al merge:', df_consolidado.sentimiento.notnull().sum())
# Out:
# Cantidad de tweets clasificados en el dataset consolidado, previo al merge: 2598

# %%
print('Cantidad de tweets clasificados en el dataset sin clasificar, previo al merge:', df_sin_clasificar.sentimiento.notnull().sum())
# Out:
# Cantidad de tweets clasificados en el dataset sin clasificar, previo al merge: 0

# %%
print('Cantidad de tweets clasificados en el dataset clasificados, previo al merge:', df_clasificados.sentimiento.notnull().sum())
# Out:
# Cantidad de tweets clasificados en el dataset clasificados, previo al merge: 2703

# %%
df_appended = df_sin_clasificar.append(df_clasificados)
print(df_appended.shape)
df_appended.head(3)
# Out:
# (19588, 8)
#           username                                              tweet  \
# 0  Elizabeth789741  alferdez alferdezprensa por favor qxsea a part...
# 1       sergistack  usas google chrome lo siento por las mayuscula...
# 2     vickyuliyapo  comodice inesazpelicueta que comiencen ya a el...
#
#                        fecha    anuncio                ubicacion  \
# 0  2020-03-19 23:04:48+00:00  Anuncio_1  Buenos Aires, Argentina
# 1  2020-03-28 20:07:18+00:00  Anuncio_1  Buenos Aires, Argentina
# 2  2020-03-19 22:57:33+00:00  Anuncio_1  Buenos Aires, Argentina
#
#              id sentimiento fecha_sola
# 0  1.240776e+18         NaN        NaN
# 1  1.243993e+18         NaN        NaN
# 2  1.240774e+18         NaN        NaN

# %%
df_consolidado = df_appended.drop_duplicates()
df_consolidado.shape
# Out:
# (19588, 8)

# %%
df_consolidado.describe()
# Out:
#                  id
# count  1.458100e+04
# mean   1.263006e+18
# std    1.820812e+16
# min    1.213622e+18
# 25%    1.244364e+18
# 50%    1.264161e+18
# 75%    1.276653e+18
# max    1.300160e+18

# %% [markdown]
# Revisamos a cuántos tweets se les impactó el valor de `sentimiento`:

# %%
print('Cantidad de tweets clasificados en el dataset, luego del merge:', df_consolidado.sentimiento.notnull().sum())
# Out:
# Cantidad de tweets clasificados en el dataset, luego del merge: 2703

# %%
df_consolidado.sentimiento.value_counts()
# Out:
# Neutral     1891
# Positivo     487
# Negativo     325
# Name: sentimiento, dtype: int64

# %%
df = df_consolidado
df.shape
# Out:
# (19588, 8)
